# %% [markdown]
# <a href="https://colab.research.google.com/github/ParvinGhaffarzadeh/Image_Processing_HomeWork/blob/main/Discrete%20Fourier%20Transform_MagnitudeSpectrum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
#Load Data
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-a03e0d55-f09e-4e73-843d-400ed1d6d70f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a03e0d55-f09e-4e73-843d-400ed1d6d70f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pic1.png to pic1.png

# %%
img = cv2.imread('pic1.png',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
